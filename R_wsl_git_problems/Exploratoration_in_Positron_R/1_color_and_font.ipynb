# %% [markdown]
# 2 space in the end of line means change line
#
# General Markdown Formatting (for both HTML and PDF where supported):
# Bold: **bold text** or __bold text__
# Italic: *italic text* or _italic text_
# Italic bold: *__italic text__* or _**italic text**_
# Strikethrough: ~~strikethrough~~
# Code: `` code ``
# Superscript: text^super^
# Subscript: text~sub~

# %% [markdown]
# 注意colab 中span 表示颜色无效，必须用
#
#
# <div style="color:red;">
# 这一整段是绿色。
# 第二行也是。
# </div>
# <div style="color:cyan">
# 这一整段是绿色。
# 第二行也是。
# </div>
# <div style="color:lightblue;">
# 这一整段是绿色。
# 第二行也是。
# </div>
# <div style="color:fuchsia;">
# 这一整段是绿色。
# 第二行也是。
# </div>
# <div style="color:teal;">
# 这一整段是绿色。
# 第二行也是。
# </div>
# <div style="color:green;">
# 这一整段是绿色。
# 第二行也是。
# </div>
# <div style="color:lime;">
# 这一整段是绿色。
# 第二行也是。
# </div>
# <div style="color:blue;">
# 这一整段是绿色。
# 第二行也是。
# </div>
# <div style="color:navy;">
# 这一整段是绿色。
# 第二行也是。
# </div>
# <div style="color:purple;">
# 这一整段是绿色。
# 第二行也是。
# </div>
# <div style="color:magenta;">
# 这一整段是绿色。
# 第二行也是。
# </div>
#
#
# <font color="fuchsia">Transforms</font>
# <font color="cyan">Transforms </font>
# <font color="blue">Transforms </font>
# <font color="red">Transforms </font>
#
# <span style="color: red;">This text is red.</span>
# <span style="color: blue;">This text is blue.</span>
# <span style="color: orange;">This text is orange.</span>
# <span style="color: yellow;">This text is yellow.</span>
# <span style="color: purple">This text is purple.</span>
# <span style="color: lightgray">This text is lightgray.</span>
# <span style="color: lightblue">This text is lightblue.</span>
# <span style="color: darkblue">This text is darkblue.</span>
# <span style="color: lime">This text is lime.</span>
# <span style="color: aqua">This text is aqua.</span>
# <span style="color: darkgreen">This text is darkgreen.</span>
# <span style="color: green">This text is green.</span>
# <span style="color: lightgreen">This text is lightgreen.</span>
# <span style="color: cyan">This text is cyan.</span>
# <span style="color: magenta">This text is magenta.</span>
# <span style="color: olive">This text is olive.</span>
# <span style="color: pink">This text is pink.</span>
# <span style="color: fuchsia">This text is fuschia.</span>

# %% [markdown]
#  16 个标准颜色关键字 (W3C/VGA 标准)这 16 个颜色是所有现代浏览器都必须支持的，也是最基础的命名颜色。
#
#  颜色关键字十六进制值颜色颜色关键字十六进制值颜色
#  black#000000⚫️
#  gray#808080🔘
#  silver#C0C0C0⚪️
#  white#FFFFFF⬜️
#  maroon#800000🔴
#  red#FF0000🟥
#  purple#800080🟪
#  fuchsia#FF00FF🟣
#  green#008000🟢
#  lime#00FF00💚
#  olive#808000🫒
#  yellow#FFFF00🟡
#  navy#000080🔵
#  blue#0000FF🟦
#  teal#008080🟦
#  aqua#00FFFF💧
#  🌈 扩展颜色关键字 (完整列表节选)
#
#
#
#  除了上述 16 种标准颜色外，$\text{CSS}$ 支持 140 多个具有名称的颜色关键字，它们大多源自 $\text{X11}$ 颜色系统，包括各种深浅不一的颜色。以下是部分常用的扩展颜色关键字：浅色系 (Light)AliceBlueLavenderMintCreamLightYellowLightCyanSnowHoneydew深色系 (Dark)DarkRedDarkGreenDarkBlueDarkGrayDarkKhakiDimGray暖色系 (Warm)OrangeGoldCoralTomatoIndianRedSaddleBrown冷色系 (Cool)CyanTurquoiseSkyBlueSteelBlueMediumSeaGreenIndigo灰色系 (Grey)SilverLightGraySlateGrayDarkSlateGray

# %% [markdown]
# <span style="color: #FF5733;">This text uses a hexadecimal color code.</span>

# %% [markdown]
# #### list
#
# ordered:
#
# 1. Main item one
#     1. Sub-item one
#     1. Sub-item two
# 2. Main item two
#     1. Another sub-item
#
#
# unordered 1:
#
# * Item 1
# * Item 2
#   * Nested Item 2.1
#   * Nested Item 2.2
#
#
# unordered 2:
#
# + Item 3
# + Item 4
# + Item 4
#
# unordered 1:
#
# - Item 3
# - Item 4
# - Item 4
