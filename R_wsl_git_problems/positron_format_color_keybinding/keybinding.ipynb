# %%
看快捷键，
有三个level 

Jupyter
Notebook
Positron

我发现positron 起作用，其他两个level 要不删除，要不设置完全一样，
如图 keybinding.png

# %% [markdown]
# Alt + Up   move line up
# Alt + down   move line down
#
# Shift + Alt + down   copy line down
#
# Ctrl + Alt + Up   move whole cell up, but first move cursor outside of cell
# Ctrl + Alt + down   move whole down, but first move cursor outside of cell
