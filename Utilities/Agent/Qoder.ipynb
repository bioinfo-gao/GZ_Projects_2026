# %% [markdown]
# 从positron 登陆 Qoder 有问题
#
# 我的方法是用 阿里云登录 Qoder， 成功后无法返回，只提示返回vscode，打开之后是vscode 界面而不是 positron 界面
# （alakas.philly@gmail.colm）
# 我的办法是回到positron 再点第一个选项，登录淘宝账号，这里直接显示成功，并返回positron，
#
# 那么我们能顺利登陆
