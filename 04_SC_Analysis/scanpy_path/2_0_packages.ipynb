# %%
# Alt + upper-arrow # move the current line up
# Alt + upper-arrow # move the current line up
# Ctrl+ Alt + upper-arrow # move the current cell up, but you have to move out the cell first
# shift + Alt + down-arrow # copy  the current cell down

# %%
# Alt + upper-arrow # move the current line up
## Ctrl+ Alt + upper-arrow # move the current cell up, but you have to move out the cell first
# 
# Alt + upper-arrow # move the current line up， but you have to move out the cell first

# shift + Alt + down-arrow # copy  the current cell down

# %%
# pip install uv # uv is a package for calculating the UV index， 目前我只发现了在terminal中 安装的方法

# %%
# uv is a package for calculating the UV index， 目前我只发现了在terminal中 安装mumba的方法
#　uv pip install numba

# %%
# Jupyter notebook 的代码单元格中直接写的，但 Jupyter notebook 无法直接执行 shell 命令,
# 除非使用 ! 前缀。

# %%
# mamba activate qc_env # IN Terminal
# Out:
# Your parent process name is Name:	python.
# If your shell is xonsh, please use "-s xonsh".
#
# 'mamba' is running as a subprocess and can't modify the parent shell.
# Thus you must initialize your shell before using activate and deactivate.
#
# To initialize the current bash shell, run:
#     $ eval "$(mamba shell hook --shell bash)"
# and then activate or deactivate with:
#     $ mamba activate
# To automatically initialize all future (bash) shells, run:
#     $ mamba shell init --shell bash --root-prefix=~/.local/share/mamba
# If your shell was already initialized, reinitialize your shell with:
#     $ mamba shell reinit --shell bash
# Otherwise, this may be an issue. In the meantime you can run commands. See:
#     $ mamba run --help
#
# Supported shells are {bash, zsh, csh, posix, xonsh, cmd.exe, powershell, fish, nu}.
# critical libmamba Shell not initialized

# %%
# 通过 curl 安装\n,
# !curl -fsSL https://pixi.sh/install.sh | bash\n

# 或者通过 conda/mamba\n
# !mamba install -c conda-forge pixi -y
# Out:
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64 ━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# bioconda/linux-64    ━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# bioconda/noarch      ━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/linux-64   ━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# conda-forge/noarch   ━━━━━━━╸━━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# bioconda/linux-64    ━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.2s
# ...

# %%
# 根据您的 pixi 项目配置，您不需要单独安装 scanpy。
# 您的 /home/gao/projects/04_SC_Analysis/pixi.toml 文件中已经包含了 scanpy 作为依赖项：

# 安装项目中定义的所有依赖（包括 scanpy）\n,
#!cd /home/gao/projects/04_SC_Analysis && pixi install
# !cd /Work_bio/gao/projects/04_SC_Analysis && pixi install

# 这将根据您的 pixi.toml 文件安装所有指定的依赖包，包括： 
# scanpy 和相关的 Python 包（anndata, pandas, numpy, scikit-learn, matplotlib, seaborn, numba）,

# R 包（r-seurat, r-dplyr, r-ggplot2 等）,

# 生物信息学工具（samtools, bedtools）
# 其他核心依赖
# Out:
# Error:   × could not find pixi.toml or pyproject.toml with tool.pixi at directory /
#   │ Work_bio/gao/projects/04_SC_Analysis

# %%
# 验证 scanpy 是否正确安装\n,
# !cd /home/gao/projects/04_SC_Analysis && pixi run python -c "import scanpy; print(f'Scanpy version: {scanpy.__version__}') "
# Out:
# ⠄ activating environment                                                        <string>:1: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
# Scanpy version: 1.11.5
