# %%
# 推荐方案 B：使用 Pip 安装（最稳妥的方法）
# 在单细胞分析环境（如包含 Scanpy 的环境）中，由于依赖链非常复杂且严重依赖 conda-forge，使用 Mamba 安装 PyTorch 经常会导致“环境不可解 (Unsolvable)”。
# 在 WSL 环境中，通常更建议在 Mamba 环境内使用 Pip 安装 PyTorch，这样可以避开 Conda 的底层 C 库冲突：
# 确保你已激活环境：conda activate scanpy_env
# 直接运行以下命令：

pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# 这种方式不会破坏你已有的 Scanpy 依赖，且能完美支持 CUDA 加速。

# %%
# 验证关键依赖是否可用，特别是 torch 和 omicverse
import torch
import scanpy as sc
import omicverse as ov

# 检查 GPU 加速是否可用
print("PyTorch CUDA是否可用:", torch.cuda.is_available())
# 修改说明: add GPU model and CUDA version output

if torch.cuda.is_available():
    print("GPU型号:", torch.cuda.get_device_name(0))
    print("CUDA版本:", torch.version.cuda)
else:
    print("GPU型号:", "N/A")
    print("CUDA版本:", "N/A")
# Out:
# PyTorch CUDA是否可用: True
# GPU型号: NVIDIA GeForce RTX 3060 Laptop GPU
# CUDA版本: 12.1
