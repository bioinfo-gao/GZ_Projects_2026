# %%
# # 1. 创建环境 (建议 python=3.12 以获得最佳兼容性)
# mamba create -n scRNA python=3.12 -y
# # 您的 Shell（Bash）尚未初始化 Mamba 的环境函数。在 Linux 中，activate 命令需要修改当前 Shell 的环境变量，因此必须先通过“挂钩（hook）”将 Mamba 注入到 Bash 中
# #第一步：永久初始化 Shell
# mamba shell init --shell bash
# source ~/.bashrc
# # 2. 激活环境
# mamba activate scRNA

# %%
# # 1. 安装 scanpy 和 ipykernel
# mamba install scanpy ipykernel -c conda-forge -c bioconda -y
# # 2. 安装 omicverse (及其常用依赖)
# pip install omicverse -i https://pypi.tuna.tsinghua.edu.cn/simple

# %%
# python -m ipykernel install --user --name scRNA --display-name "Python (scRNA)"

# %%
import warnings
warnings.filterwarnings("ignore")

import scanpy as sc
import omicverse as ov
import pandas as pd
# Out:
# /home/gao/micromamba/envs/scRNA/lib/python3.12/site-packages/torch/cuda/__init__.py:65: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# /home/gao/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/utils/registry.py:104: UserWarning: Function 'omicverse.bulk._Enrichment.pyGSEA' is missing a docstring; agent help output may be limited.
#   warnings.warn(
# /home/gao/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/utils/registry.py:104: UserWarning: Function 'omicverse.bulk._network.pyPPI' is missing a docstring; agent help output may be limited.
#   warnings.warn(
# /home/gao/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/utils/registry.py:104: UserWarning: Function 'omicverse.pl._palette.ForbiddenCity' is missing a docstring; agent help output may be limited.
#   warnings.warn(
# /home/gao/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/utils/registry.py:104: UserWarning: Function 'omicverse.pl._single.embedding_density' is missing a docstring; agent help output may be limited.
#   warnings.warn(
# /home/gao/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/utils/registry.py:104: UserWarning: Function 'omicverse.pl._single.bardotplot' is missing a docstring; agent help output may be limited.
#   warnings.warn(
# /home/gao/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/utils/registry.py:104: UserWarning: Function 'omicverse.pl._single.contour' is missing a docstring; agent help output may be limited.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import scanpy as sc
# ----> 2 import omicverse as ov
#       3 import pandas as pd
#       5 print(f"Scanpy version: {sc.__version__}")
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/__init__.py:59
#      57 # Core submodules - direct imports
#      58 from . import alignment
# ---> 59 from . import bulk
#      60 from . import single
#      61 from . import utils
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/bulk/__init__.py:44
#      42 from ._network import pyPPI,string_interaction,string_map,generate_G
#      43 from ._chm13 import get_chm13_gene,find_chm13_gene
# ---> 44 from ._Deseq2 import pyDEG,deseq2_normalize,estimateSizeFactors,estimateDispersions,Matrix_ID_mapping,data_drop_duplicates_index
#      45 from ._tcga import pyTCGA
#      46 from ._combat import batch_correction
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/bulk/_Deseq2.py:16
#      14 from ..utils import plot_boxplot
#      15 from ..utils.registry import register_function
# ---> 16 from ..pl import volcano
#      18 @register_function(
#      19     aliases=["基因ID映射", "gene_id_mapping", "id_mapping", "基因符号转换", "gene_symbol_mapping"],
#      20     category="bulk",
#    (...)     27 )
#      28 def Matrix_ID_mapping(data:pd.DataFrame,gene_ref_path:str,keep_unmapped:bool=True)->pd.DataFrame:
#      29     r"""Map gene IDs in the input data to gene symbols using a reference table.
#      30
#      31     Arguments:
#    (...)     38
#      39     """
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/pl/__init__.py:58
#      56 from ._bulk import *
#      57 from ._space import *
# ---> 58 from ._cpdb import *
#      59 from ._flowsig import *
#      60 from ._embedding import embedding_atlas
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/pl/_cpdb.py:12
#       9 from matplotlib.collections import LineCollection
#      10 from matplotlib.patches import FancyArrowPatch
# ---> 12 from ..single import cpdb_exact_target,cpdb_exact_source
#      13 from ._cpdbviz import CellChatViz
#      15 def cpdb_network(adata:anndata.AnnData,interaction_edges:pd.DataFrame,
#      16                       celltype_key:str,nodecolor_dict=None,count_min=50,
#      17                        source_cells=None,target_cells=None,
#    (...)     20                       fontsize:int=12,ax=None,
#      21                      return_graph:bool=False):
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/single/__init__.py:51
#      47 # Heavy functionality lives in submodules and is imported lazily.
#      48
#      49 # Core gene selection and differential expression
#      50 from ._cosg import cosg
# ---> 51 from ._anno import pySCSA,MetaTiME,scanpy_lazy,scanpy_cellanno_from_dict,get_celltype_marker
#      52 from ._nocd import scnocd
#      53 from ._mofa import (
#      54     pyMOFAART,pyMOFA,GLUE_pair,
#      55     factor_exact,factor_correlation,
#    (...)     59     plot_factors_violin,plot_weights,
#      60 )
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/single/_anno.py:12
#      10 import requests
#      11 import anndata
# ---> 12 from ..pp._preprocess import scale
#      13 from ..utils import gen_mpl_labels
#      15 from .._settings import add_reference
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/pp/__init__.py:70
#       1 r"""
#       2 Preprocessing utilities for single-cell and bulk omics data.
#       3
#    (...)     53     >>> ov.pp.umap(adata)
#      54 """
#      56 from ._preprocess import (identify_robust_genes,
#      57                           select_hvf_pegasus,
#      58                           highly_variable_features,
#    (...)     67                           pca,score_genes_cell_cycle,
#      68                           leiden,umap,louvain,anndata_to_GPU,anndata_to_CPU,mde,tsne)
# ---> 70 from ._sude import sude
#      72 from ._qc import qc,filter_cells,filter_genes
#      73 from ._recover import recover_counts,binary_search
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/pp/_sude.py:13
#      10 from .._settings import settings, EMOJI, Colors
#      11 from ..utils.registry import register_function
# ---> 13 from ..external.sude_py import sude as sude_py
#      15 if TYPE_CHECKING:
#      16     from typing import Literal
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/external/__init__.py:62
#       1 r"""
#       2 External algorithms and specialized methods collection.
#       3
#    (...)     60     - Regular updates incorporate latest algorithmic advances
#      61 """
# ---> 62 from . import (scSLAT,CEFCON,mofapy2,GNTD,spaceflow,STT,
#      63                tosica,STAGATE_pyG,STAligner,spatrio,PROST,cytotrace2,
#      64                GraphST,commot,cnmf,starfysh,scMulan,flowsig,PyWGCNA,
#      65                CAST,scanorama,scdiffusion,BINARY,cellanova,VIA,gaston,pyscenic,
#      66                 bin2cell,sude_py,harmony
#      67                )
#      68 __all__ = [
#      69     'scSLAT',
#      70     'CEFCON',
#    (...)     98     'harmony',
#      99 ]
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/external/scSLAT/__init__.py:7
#       1 r"""
#       2 SLAT (Spatial-Linked Alignment Tool)
#       3 """
#       6 from . import viz
# ----> 7 from . import model
#       9 name = "scSLAT"
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/external/scSLAT/model/__init__.py:4
#       1 r"""
#       2 Core functions of SLAT model
#       3 """
# ----> 4 from .utils import *
#       5 from .loaddata import load_anndata, load_anndatas
#       6 from .preprocess import Cal_Spatial_Net, scanpy_workflow
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/external/scSLAT/model/utils.py:21
#      19 from ..utils import get_free_gpu
#      20 from .train import train_GAN, train_reconstruct
# ---> 21 from .graphmodel import LGCN, LGCN_mlp, WDiscriminator, ReconDNN
#      22 from .loaddata import load_anndatas
#      23 from .preprocess import Cal_Spatial_Net
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/external/scSLAT/model/graphmodel.py:9
#       6 import torch
#       7 import torch.nn.functional as F
# ----> 9 from .graphconv import CombUnweighted
#      12 class LGCN(torch.nn.Module):
#      13     r"""
#      14     Lightweight GCN which remove nonlinear functions and concatenate the embeddings of each layer:
#      15         (:math:`Z = f_{e}(A, X) = Concat( [X, A_{X}, A_{2X}, ..., A_{KX}])W_{e}`)
#    (...)     22         LGCN layers
#      23     """
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/external/scSLAT/model/graphconv/__init__.py:4
#       1 r"""
#       2 Graph convolution network
#       3 """
# ----> 4 from .combnet import CombUnweighted
#
# File ~/micromamba/envs/scRNA/lib/python3.12/site-packages/omicverse/external/scSLAT/model/graphconv/combnet.py:4
#       1 from typing import List, Optional, Union, Any
#       3 import torch
# ----> 4 from torch_geometric.nn.conv import MessagePassing
#       5 from torch_geometric.utils import add_remaining_self_loops
#       7 def sym_norm(edge_index:torch.Tensor,
#       8              num_nodes:int,
#       9              edge_weight:Optional[Union[Any,torch.Tensor]]=None,
#      10              improved:Optional[bool]=False,
#      11              dtype:Optional[Any]=None
#      12     )-> List:
#
# ModuleNotFoundError: No module named 'torch_geometric'

# %%
print(f"Scanpy version: {sc.__version__}")
print(f"OmicVerse version: {ov.__version__}")
# Out:
# Scanpy version: 1.11.5
# /tmp/ipykernel_15903/967341823.py:1: FutureWarning: `__version__` is deprecated, use `importlib.metadata.version('scanpy')` instead
#   print(f"Scanpy version: {sc.__version__}")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 print(f"Scanpy version: {sc.__version__}")
# ----> 2 print(f"OmicVerse version: {ov.__version__}")
#
# NameError: name 'ov' is not defined

# %%
ov.utils.ov_plot_set()
# Out:
# The kernel failed to start as the Python Environment 'R43 (Python -1.-1.-1)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.
