# %% [markdown]
# ### 150bp 物理过滤：任务完成报告
#
# | 产出类别 | 物理路径 | 关键文件名 | 用途 |
# | :--- | :--- | :--- | :--- |
# | **最终矩阵** | `Final_Filtered_Results/counts/` | `filtered_counts_v150_matrix.txt` | **核心数据**：直接导入 R 语言进行差异分析和 PCA。 |
# | **干净BAM** | `Final_Filtered_Results/filtered_bams/` | `*_long_150.bam` | 长度合格（≥150bp）的比对文件，可用于可视化。 |
# | **降解分析** | `Final_Filtered_Results/trash_analysis/` | `*_trash_stats.txt` | **证据文件**：分析 WT_2 和 Mock_3 被剔除成分的组成。 |
